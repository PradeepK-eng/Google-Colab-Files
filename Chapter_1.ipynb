# %% [markdown]
# <a href="https://colab.research.google.com/github/PradeepK-eng/Google-Colab-Files/blob/main/Chapter_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# > All are the same _ *in Python representation:*

# %%
i = 5
print(i)

j = 10;
print(j);

k = 15; print(k);

m =20; print(m)
# Out:
# 5
# 10
# 15
# 20

# %%
i=5,4,3,2,1
print(i)
# Out:
# (5, 4, 3, 2, 1)

# %%
i  = \
5
print(i)

# %% [markdown]
# **Print(s) and print("s") are not same.**

# %%
# @title
s = 'This is string. \
This continues the string.'
print(s)
print("s")
# Out:
# This is string. This continues the string.
# s

# %% [markdown]
# Keywords are predefined; reserved words that are used in programming and they have a special meaning.
# - Python has 33 keywords:
#
# **False, None, True, and, as, assert, break, class, continue, def, del, elif, else, except, finally, for, from, global, if, import, in, is, lambda, not, or, pass, raise, return, try, while, with, and yield**

# %%
abc = 24
print(type(abc))

bcd = 64.0
print(type(bcd))

cde = -24
print(type(cde))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'int'>

# %%
'Hello World'
"Welcome to Python Class"
"""
This KPC
First class
"""
'''
What your looking?
not be clear
'''

# %%
name = "pradeep_chand"
last_name = " Kopila"
print(name + last_name)

# %%
abc = "Hello World"
print(abc[0], abc[1], abc[5], abc[6], abc[7], abc[10])

print(abc[:])

print(abc[0:5])

print(abc[6:])

# %%
abc = """ I find Python as the most intresting language of all apart
          from other programming languages. Python is a powerful, yet simple to use and easy to learn tech-savy,
          object-oriented programming langauage.
      """
print(abc.find("easy"))
print(abc.count("I"))
print(abc.count("of"))
print(abc.count("language"))

# %%
abc = "Python is a powerful, yet simple to use and easy to learn tech-savy, object-oriented programming langauage."

print(abc.capitalize())
print(abc.upper())
print(abc.lower())
print(abc.swapcase())
print(abc.title())

# %%
abc = ("     Hello World     ")
print(abc)
print(abc.center(30))
print(abc.ljust(30))
print(abc.rjust(30))

# %%
# @title
minutes = 100
percentage = (minutes *100) / 60
print(percentage)

percentage = (minutes *100) // 60
print(percentage)
