# %% [markdown]
# <a href="https://colab.research.google.com/github/PradeepK-eng/Google-Colab-Files/blob/main/Streamlit_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! pip install streamlit -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.1/9.1 MB 32.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 71.5 MB/s eta 0:00:00

# %%
# %%writefile app.py
import streamlit as st
st.write('# Hello World')
st.write('## hi hi hi')
# Out:
# Overwriting app.py

# %%
# !streamlit run app.py & npx localtunnel --port 8501
# Out:
# ⠙
# Collecting usage statistics. To deactivate, set browser.gatherUsageStats to false.
#
# ⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴Need to install the following packages:
# localtunnel@2.0.2
# Ok to proceed? (y)
#   You can now view your Streamlit app in your browser.
#
#   Local URL: http://localhost:8501
#   Network URL: http://172.28.0.12:8501
#   External URL: http://34.106.254.203:8501
#
#   Stopping...
# ^C

# %%
# !streamlit run app.py & >/content/logs.txt & npx localtunnel --port 8501
# Out:
# ⠙⠹
# Collecting usage statistics. To deactivate, set browser.gatherUsageStats to false.
#
# ⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴Need to install the following packages:
# localtunnel@2.0.2
# Ok to proceed? (y)
#   You can now view your Streamlit app in your browser.
#
#   Local URL: http://localhost:8501
#   Network URL: http://172.28.0.12:8501
#   External URL: http://34.106.254.203:8501
#
#   Stopping...
# ^C

# %%
! wget -q -o - ipv4.icanhazip.com

# %%
# !streamlit run app.py & npx localtunnel --port 8501
# Out:
# ⠙⠹
# Collecting usage statistics. To deactivate, set browser.gatherUsageStats to false.
#
# ⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦Need to install the following packages:
# localtunnel@2.0.2
# Ok to proceed? (y)
#   You can now view your Streamlit app in your browser.
#
#   Local URL: http://localhost:8501
#   Network URL: http://172.28.0.12:8501
#   External URL: http://34.106.254.203:8501
#
# y
#
# ⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴your url is: https://gold-shirts-move.loca.lt
# y
# ────────────────────────── Traceback (most recent call last) ───────────────────────────
#   /usr/local/lib/python3.12/dist-packages/streamlit/runtime/scriptrunner/exec_code.py:
#   129 in exec_func_with_error_handling
#
#   /usr/local/lib/python3.12/dist-packages/streamlit/runtime/scriptrunner/script_runner
#   .py:689 in code_to_exec
#
#   /content/app.py:4 in <module>
#
#     1 import streamlit as st
#     2 st.write('# Hello World')
#     3 st.write('## hi hi hi')
#   ❱ 4
#
#   /usr/local/lib/python3.12/dist-packages/streamlit/runtime/metrics_util.py:563 in
#   wrapped_func
# ────────────────────────────────────────────────────────────────────────────────────────
# TypeError: WriteMixin.write() got an unexpected keyword argument 'divider'
# ────────────────────────── Traceback (most recent call last) ───────────────────────────
#   /usr/local/lib/python3.12/dist-packages/streamlit/runtime/scriptrunner/exec_code.py:
#   129 in exec_func_with_error_handling
#
#   /usr/local/lib/python3.12/dist-packages/streamlit/runtime/scriptrunner/script_runner
#   .py:689 in code_to_exec
#
#   /content/app.py:4 in <module>
#
#     1 import streamlit as st
#     2 st.write('# Hello World')
#     3 st.write('## hi hi hi')
#   ❱ 4 st.write('## This is pradeep ##', divider='blue')
#     5 ## st.header('SnakeInCode is a :green[good] channel :sunglasses:' , divider='blu
#     6
#     7
#
#   /usr/local/lib/python3.12/dist-packages/streamlit/runtime/metrics_util.py:563 in
#   wrapped_func
# ────────────────────────────────────────────────────────────────────────────────────────
# TypeError: WriteMixin.write() got an unexpected keyword argument 'divider'
#   Stopping...
# ^C
